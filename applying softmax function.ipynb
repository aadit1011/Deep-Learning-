# %%
import torch 
import torch.optim as optim 
import torch.nn as nn

# %%
tens=torch.tensor([[-22202,-1290],[1280,12353]],dtype=torch.float32)
soft=nn.Softmax(dim=0)
b=soft(tens) 
b
# Out:
# tensor([[0., 0.],
#         [1., 1.]])
